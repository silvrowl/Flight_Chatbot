# %%
import numpy as np
import re

# %%
import nltk
from nltk.corpus import stopwords

# %% [markdown]
# ##Data Preprocessing

# %%
text = "There are few people whom I really love, and still fewer of whom I think well.\t The more I see of the world, the more am I dissatisfied with it; and every day confirms my belief of the inconsistency of all human characters, and of the little dependence that can be placed on the appearance of merit or sense."

# %%
text1= "I hope you're pleased with yourselves. We could all have been killed — or worse, expelled. Now if you don't mind, I'm going to bed."

# %%
#remove tabs
data_notab = re.sub('(\\t)', ' ', text)

# %%
print(data_notab)
# Out:
# There are few people whom I really love, and still fewer of whom I think well.  The more I see of the world, the more am I dissatisfied with it; and every day confirms my belief of the inconsistency of all human characters, and of the little dependence that can be placed on the appearance of merit or sense.

# %%
type(data_notab)
# Out:
# str

# %%
#to remove numbers
r = ("\d+")

# %%
# Replace all none alphanumeric characters with spaces
text = re.sub(r'[^a-zA-Z0-9\s]', ' ', text)
# text = re.sub(r, ' ', text)

# %% [markdown]
# ###Tokenization

# %%
import pprint

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
#split into sentences
from nltk.tokenize import sent_tokenize
tokenized_sent=sent_tokenize(data_notab)
print(tokenized_sent)
# Out:
# ['There are few people whom I really love, and still fewer of whom I think well.', 'The more I see of the world, the more am I dissatisfied with it; and every day confirms my belief of the inconsistency of all human characters, and of the little dependence that can be placed on the appearance of merit or sense.']

# %%
len(tokenized_sent)
# Out:
# 2

# %%
#split into words
from nltk.tokenize import word_tokenize
tokenized_words = []
tokenized_words.extend(word for word in word_tokenize(str(tokenized_sent)))
print(tokenized_words)
# Out:
# ['[', "'There", 'are', 'few', 'people', 'whom', 'I', 'really', 'love', ',', 'and', 'still', 'fewer', 'of', 'whom', 'I', 'think', 'well', '.', "'", ',', "'The", 'more', 'I', 'see', 'of', 'the', 'world', ',', 'the', 'more', 'am', 'I', 'dissatisfied', 'with', 'it', ';', 'and', 'every', 'day', 'confirms', 'my', 'belief', 'of', 'the', 'inconsistency', 'of', 'all', 'human', 'characters', ',', 'and', 'of', 'the', 'little', 'dependence', 'that', 'can', 'be', 'placed', 'on', 'the', 'appearance', 'of', 'merit', 'or', 'sense', '.', "'", ']']

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stop_words = stopwords.words('english')
print(stop_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
[word for word in word_tokenize(str(tokenized_sent)) if word not in stop_words]
# Out:
# ['[',
#  "'There",
#  'people',
#  'I',
#  'really',
#  'love',
#  ',',
#  'still',
#  'fewer',
#  'I',
#  'think',
#  'well',
#  '.',
#  "'",
#  ',',
#  "'The",
#  'I',
#  'see',
#  'world',
#  ',',
#  'I',
#  'dissatisfied',
#  ';',
#  'every',
#  'day',
#  'confirms',
#  'belief',
#  'inconsistency',
#  'human',
#  'characters',
#  ',',
#  'little',
#  'dependence',
#  'placed',
#  'appearance',
#  'merit',
#  'sense',
#  '.',
#  "'",
#  ']']

# %% [markdown]
# ###Punctuation & Lower case

# %%
#lowercase
data_lower = tokenized_sent[0].lower()

print(data_lower)
# Out:
# there are few people whom i really love, and still fewer of whom i think well.

# %%
#Remove punctuation
import string
print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
no_punct = [t for t in tokenized_words if t not in string.punctuation]
print(no_punct)
# Out:
# ["'There", 'are', 'few', 'people', 'whom', 'I', 'really', 'love', 'and', 'still', 'fewer', 'of', 'whom', 'I', 'think', 'well', "'The", 'more', 'I', 'see', 'of', 'the', 'world', 'the', 'more', 'am', 'I', 'dissatisfied', 'with', 'it', 'and', 'every', 'day', 'confirms', 'my', 'belief', 'of', 'the', 'inconsistency', 'of', 'all', 'human', 'characters', 'and', 'of', 'the', 'little', 'dependence', 'that', 'can', 'be', 'placed', 'on', 'the', 'appearance', 'of', 'merit', 'or', 'sense']

# %%
data_lower = [w.lower() for w in no_punct]
print(data_lower)
# Out:
# ["'there", 'are', 'few', 'people', 'whom', 'i', 'really', 'love', 'and', 'still', 'fewer', 'of', 'whom', 'i', 'think', 'well', "'the", 'more', 'i', 'see', 'of', 'the', 'world', 'the', 'more', 'am', 'i', 'dissatisfied', 'with', 'it', 'and', 'every', 'day', 'confirms', 'my', 'belief', 'of', 'the', 'inconsistency', 'of', 'all', 'human', 'characters', 'and', 'of', 'the', 'little', 'dependence', 'that', 'can', 'be', 'placed', 'on', 'the', 'appearance', 'of', 'merit', 'or', 'sense']

# %% [markdown]
# ###Stop Words

# %%
filtered_sent=[]
for w in no_punct:
    if w not in stop_words:
        filtered_sent.append(w)

# %%
# filtered_sent
no_punct = [t for t in filtered_sent if t not in string.punctuation]
no_punct = [w.lower() for w in no_punct]
no_punct
# Out:
# ["'there",
#  'people',
#  'i',
#  'really',
#  'love',
#  'still',
#  'fewer',
#  'i',
#  'think',
#  'well',
#  "'the",
#  'i',
#  'see',
#  'world',
#  'i',
#  'dissatisfied',
#  'every',
#  'day',
#  'confirms',
#  'belief',
#  'inconsistency',
#  'human',
#  'characters',
#  'little',
#  'dependence',
#  'placed',
#  'appearance',
#  'merit',
#  'sense']

# %% [markdown]
# ###Stemmer

# %%
from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer

ps= PorterStemmer()
ls = LancasterStemmer()

# %%
psstemmed_words=[]
lsstemmed_words = []
for w in no_punct:

  psstemmed_words.append(ps.stem(w))

  lsstemmed_words.append(ls.stem(w))
 
  print("Words "+w+ "    PS :"+ps.stem(w) + "     LS : "+ls.stem(w))
# Out:
# Words 'there    PS :'there     LS : 'there
# Words people    PS :peopl     LS : peopl
# Words i    PS :i     LS : i
# Words really    PS :realli     LS : real
# Words love    PS :love     LS : lov
# Words still    PS :still     LS : stil
# Words fewer    PS :fewer     LS : few
# Words i    PS :i     LS : i
# Words think    PS :think     LS : think
# Words well    PS :well     LS : wel
# Words 'the    PS :'the     LS : 'the
# Words i    PS :i     LS : i
# Words see    PS :see     LS : see
# Words world    PS :world     LS : world
# Words i    PS :i     LS : i
# Words dissatisfied    PS :dissatisfi     LS : dissatisfy
# Words every    PS :everi     LS : every
# Words day    PS :day     LS : day
# Words confirms    PS :confirm     LS : confirm
# Words belief    PS :belief     LS : believ
# Words inconsistency    PS :inconsist     LS : inconsist
# Words human    PS :human     LS : hum
# Words characters    PS :charact     LS : charact
# Words little    PS :littl     LS : littl
# ...

# %% [markdown]
# ###Lemmatizer

# %%
from nltk.stem.wordnet import WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
lem = WordNetLemmatizer()
for word in no_punct:
    print ("{0:20}{1:20}".format(word,lem.lemmatize(word, pos ="v")))
# Out:
# 'there              'there
# people              people
# i                   i
# really              really
# love                love
# still               still
# fewer               fewer
# i                   i
# think               think
# well                well
# 'the                'the
# i                   i
# see                 see
# world               world
# i                   i
# dissatisfied        dissatisfy
# every               every
# day                 day
# confirms            confirm
# belief              belief
# inconsistency       inconsistency
# human               human
# characters          character
# little              little
# dependence          dependence
# placed              place
# appearance          appearance
# merit               merit
# sense               sense

# %% [markdown]
# ###POS TAG

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
tagged_words = nltk.pos_tag(filtered_sent)

# %%
import pprint as pprint

# %%
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(tagged_words)
# Out:
# [   ("'There", 'RB'),
#     ('people', 'NNS'),
#     ('I', 'PRP'),
#     ('really', 'RB'),
#     ('love', 'VB'),
#     ('still', 'RB'),
#     ('fewer', 'JJR'),
#     ('I', 'PRP'),
#     ('think', 'VBP'),
#     ('well', 'RB'),
#     ("'The", 'CD'),
#     ('I', 'PRP'),
#     ('see', 'VBP'),
#     ('world', 'NN'),
#     ('I', 'PRP'),
#     ('dissatisfied', 'VBD'),
#     ('every', 'DT'),
#     ('day', 'NN'),
#     ('confirms', 'VBZ'),
#     ('belief', 'JJ'),
#     ('inconsistency', 'NN'),
#     ('human', 'JJ'),
#     ('characters', 'NNS'),
#     ('little', 'JJ'),
#     ('dependence', 'NN'),
#     ('placed', 'VBD'),
#     ('appearance', 'NN'),
#     ('merit', 'NN'),
#     ('sense', 'NN')]

# %%
# ?nltk.pos_tag

# %% [markdown]
# ###Common and Sparse Words

# %%
#Most common and sparse words
from nltk.probability import FreqDist
fdist = FreqDist(tokenized_words)
fdist.most_common(5)
# Out:
# [('of', 6), ('the', 5), ('I', 4), (',', 4), ('and', 3)]

# %%
tag_word = nltk.FreqDist(tag for (word, tag) in tagged_words)
tag_word.most_common()
# Out:
# [('NN', 7),
#  ('RB', 4),
#  ('PRP', 4),
#  ('JJ', 3),
#  ('NNS', 2),
#  ('VBP', 2),
#  ('VBD', 2),
#  ('VB', 1),
#  ('JJR', 1),
#  ('CD', 1),
#  ('DT', 1),
#  ('VBZ', 1)]

# %% [markdown]
# ###N-grams

# %%
from nltk import bigrams, trigrams
from nltk import ngrams

bi_grams = list(bigrams(tokenized_words))
tri_grams = list(trigrams(tokenized_words))
output = list(ngrams(tokenized_words, 5))

# %%
print(bi_grams)
# Out:
# [('[', "'There"), ("'There", 'are'), ('are', 'few'), ('few', 'people'), ('people', 'whom'), ('whom', 'I'), ('I', 'really'), ('really', 'love'), ('love', ','), (',', 'and'), ('and', 'still'), ('still', 'fewer'), ('fewer', 'of'), ('of', 'whom'), ('whom', 'I'), ('I', 'think'), ('think', 'well'), ('well', '.'), ('.', "'"), ("'", ','), (',', "'The"), ("'The", 'more'), ('more', 'I'), ('I', 'see'), ('see', 'of'), ('of', 'the'), ('the', 'world'), ('world', ','), (',', 'the'), ('the', 'more'), ('more', 'am'), ('am', 'I'), ('I', 'dissatisfied'), ('dissatisfied', 'with'), ('with', 'it'), ('it', ';'), (';', 'and'), ('and', 'every'), ('every', 'day'), ('day', 'confirms'), ('confirms', 'my'), ('my', 'belief'), ('belief', 'of'), ('of', 'the'), ('the', 'inconsistency'), ('inconsistency', 'of'), ('of', 'all'), ('all', 'human'), ('human', 'characters'), ('characters', ','), (',', 'and'), ('and', 'of'), ('of', 'the'), ('the', 'little'), ('little', 'dependence'), ('dependence', 'that'), ('that', 'can'),
# ...

# %%
print(tri_grams)
# Out:
# [('[', "'There", 'are'), ("'There", 'are', 'few'), ('are', 'few', 'people'), ('few', 'people', 'whom'), ('people', 'whom', 'I'), ('whom', 'I', 'really'), ('I', 'really', 'love'), ('really', 'love', ','), ('love', ',', 'and'), (',', 'and', 'still'), ('and', 'still', 'fewer'), ('still', 'fewer', 'of'), ('fewer', 'of', 'whom'), ('of', 'whom', 'I'), ('whom', 'I', 'think'), ('I', 'think', 'well'), ('think', 'well', '.'), ('well', '.', "'"), ('.', "'", ','), ("'", ',', "'The"), (',', "'The", 'more'), ("'The", 'more', 'I'), ('more', 'I', 'see'), ('I', 'see', 'of'), ('see', 'of', 'the'), ('of', 'the', 'world'), ('the', 'world', ','), ('world', ',', 'the'), (',', 'the', 'more'), ('the', 'more', 'am'), ('more', 'am', 'I'), ('am', 'I', 'dissatisfied'), ('I', 'dissatisfied', 'with'), ('dissatisfied', 'with', 'it'), ('with', 'it', ';'), ('it', ';', 'and'), (';', 'and', 'every'), ('and', 'every', 'day'), ('every', 'day', 'confirms'), ('day', 'confirms', 'my'), ('confirms', 'my', 'belief'), ('my', 
# ...

# %%
print(output)
# Out:
# [('[', "'There", 'are', 'few', 'people'), ("'There", 'are', 'few', 'people', 'whom'), ('are', 'few', 'people', 'whom', 'I'), ('few', 'people', 'whom', 'I', 'really'), ('people', 'whom', 'I', 'really', 'love'), ('whom', 'I', 'really', 'love', ','), ('I', 'really', 'love', ',', 'and'), ('really', 'love', ',', 'and', 'still'), ('love', ',', 'and', 'still', 'fewer'), (',', 'and', 'still', 'fewer', 'of'), ('and', 'still', 'fewer', 'of', 'whom'), ('still', 'fewer', 'of', 'whom', 'I'), ('fewer', 'of', 'whom', 'I', 'think'), ('of', 'whom', 'I', 'think', 'well'), ('whom', 'I', 'think', 'well', '.'), ('I', 'think', 'well', '.', "'"), ('think', 'well', '.', "'", ','), ('well', '.', "'", ',', "'The"), ('.', "'", ',', "'The", 'more'), ("'", ',', "'The", 'more', 'I'), (',', "'The", 'more', 'I', 'see'), ("'The", 'more', 'I', 'see', 'of'), ('more', 'I', 'see', 'of', 'the'), ('I', 'see', 'of', 'the', 'world'), ('see', 'of', 'the', 'world', ','), ('of', 'the', 'world', ',', 'the'), ('the', 'world', ',
# ...

# %% [markdown]
# ##Word2Vec

# %%
# %pip install gensim -qq

# %%
import gensim

# %% [markdown]
# The advantage of using Gensim, is that it can easily process large datasets, continuous streaming datasets, etc.

# %%
filtered_sent

# %%
sentences = [['first', 'sentence'], ['second', 'sentence']]
# train word2vec on the two sentences
model = gensim.models.Word2Vec(sentences, min_count=1)

# %% [markdown]
# This link contains the full list of parameters that are available for hypertuning: [link](https://radimrehurek.com/gensim/models/word2vec.html#gensim.models.word2vec.Word2Vec)

# %%
model

# %%
vocab = list(model.wv.vocab)
X = model[vocab]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X)

# %%
import pandas as pd

# %%
df = pd.DataFrame(X_tsne, index=vocab, columns=['x', 'y'])

# %%
df.head()
# Out:
#                    x           y
# first     502.224915 -242.180573
# sentence  446.140656 -352.342316
# second    378.779877 -248.691299

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.scatter(df['x'], df['y'])
for word, pos in df.iterrows():
    ax.annotate(word, pos)

# %% [markdown]
# You can load a stored model and retrain it with more data

# %%
model = gensim.models.Word2Vec.load('/tmp/mymodel')
model.train(more_sentences)

# %% [markdown]
# ##NER

# %%
# %pip install spacy -qq

# %%
import nltk, nltk.tag, nltk.chunk
import spacy
import pprint as pprint
from gensim.summarization import summarize
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
text
# Out:
# 'There are few people whom I really love  and still fewer of whom I think well \t The more I see of the world  the more am I dissatisfied with it  and every day confirms my belief of the inconsistency of all human characters  and of the little dependence that can be placed on the appearance of merit or sense '

# %%
doc = nlp(text)

# %%
print([(X.text, X.label_) for X in doc.ents])
# Out:
# []

# %% [markdown]
# Let us try to do this by pulling an article from BBC

# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html5lib')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

# %%
ny_bb = url_to_string('https://raw.githubusercontent.com/nihitx/game-of-thrones-/master/gameofthrones.txt')
article = nlp(ny_bb)
len(article.ents)

# %%
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'ORG': 35, 'PERSON': 22, 'GPE': 21, 'DATE': 12, 'CARDINAL': 7, 'NORP': 5, 'PRODUCT': 2, 'QUANTITY': 1, 'ORDINAL': 1, 'WORK_OF_ART': 1, 'LOC': 1})

# %%
#Print a random sentence in the article
sentences = [x for x in article.sents]
print(sentences[40])
# Out:
# on."Mr Messervy-Gross said he had kept the shoes after finishing the race, adding that they were still in a wearable condition.

# %% [markdown]
# So if you would like to visualise this NER, you can use displacy

# %%
from spacy import displacy

# %%
displacy.render(nlp(str(sentences[30:40])), jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">[Can exercise reverse the ageing process?, Guide dogs lead blind
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     half
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# -marathon runner, It was a &quot;somewhat intimidating&quot; prospect, the 47-year-old told
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Radio 5 Live's
# ...

# %% [markdown]
# ##Sentiment Analysis

# %%
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-34bcd940-31a4-4237-bee9-0a5264fe1e15" name="files[]" multiple disabled />
#      <output id="result-34bcd940-31a4-4237-bee9-0a5264fe1e15">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving SCA Analytics Brief - Feedback Submissions new.csv to SCA Analytics Brief - Feedback Submissions new.csv
# ...

# %%
df = pd.read_csv('/content/SCA Analytics Brief - Feedback Submissions new.csv')

# %%
df.head()
# Out:
#             Timestamp  Game Date  ...  Player type  NPS type
# 0   3/8/2019 20:42:35   3/8/2019  ...  First-timer   Passive
# 1   3/8/2019 20:43:10   3/8/2019  ...  First-timer  Promoter
# 2  3/13/2019 20:26:45  3/13/2019  ...   Enthusiast  Promoter
# 3  3/14/2019 21:14:28  3/14/2019  ...   Enthusiast  Promoter
# 4  3/17/2019 11:43:08  3/15/2019  ...  First-timer  Promoter
#
# [5 rows x 20 columns]

# %%
col1 = df["Did you have a favourite moment? If so, what was it?"].fillna("")

# %%
col2 = df["If you have any other feedback, please leave it here. "].fillna("")

# %%
len(col1)
# Out:
# 470

# %%
col1 = [re.sub(r'[^a-zA-Z0-9 \n]', ' ', comment) for comment in col1]

# %%
col1
# Out:
# ['Keys', 'How interactive it was', 'Group photo', 'The chalkboard erasing puzzle', 'I loved when we were under pressure to finish on time ', 'Actors', 'Stimulation', 'Actors and quality of puzzles', 'Working with the  actors ', 'Clues', 'Ingeractive', 'Teamwork', 'Actors', 'Figuring out the actors part of the game', 'Getting a clue co pleted', 'Well themed', 'Cell', 'The actor', 'Getting the clues', 'Love the actors', 'The actors', 'The players', 'Finding the keys', 'Puzzle', 'Finding the final key', 'Interaction', 'Great puzzles together', 'Games', 'The clues', 'interacting with the actors  It was really cool to have them be part of the game in there so that they can give helpful side comments without having to waste time trying to figure out how far you are in the game ', 'The two characters', 'Interacting with the prisoner and letting him out ', 'The jail break', 'The acting part  ', 'Actors', 'Actors\n', 'Finding the music notes\n', 'The actors', 'Interactive aspect with roleplay
# ...

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from textblob import TextBlob, Word, Blobber

# %%
import pandas_profiling as pp

# %%
pp.ProfileReport(df)

# %%
df.info()

# %%
df["sentiment"] = df["If you have any other feedback, please leave it here. "].map(lambda text: TextBlob(str(text)).sentiment.polarity)

# %%
df.head()

# %%
col2

# %%
TextBlob("I hate it").sentiment.polarity
# Out:
# -0.8

# %%
#split into sentences
from nltk.tokenize import sent_tokenize
tokenized_sent=sent_tokenize(col1)
print(tokenized_sent)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-132-7f658027c8b0> in <module>()
#       1 from nltk.tokenize import sent_tokenize
# ----> 2 tokenized_sent=sent_tokenize(col1)
#       3 print(tokenized_sent)
#
# /usr/local/lib/python3.6/dist-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#      93     """
#      94     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
# ---> 95     return tokenizer.tokenize(text)
#      96
#      97 # Standard word tokenizer.
#
# /usr/local/lib/python3.6/dist-packages/nltk/tokenize/punkt.py in tokenize(self, text, realign_boundaries)
#    1235         Given a text, returns a list of the sentences in that text.
#    1236         """
# -> 1237         return list(self.sentences_from_text(text, realign_boundaries))
#    1238
#    1239     def debug_decisions(self, text):
#
# ...

# %% [markdown]
# ##Topic Modelling

# %%
import os
import numpy as np
import pandas as pd
import re
from pprint import pprint

# %%
# %pip install pyLDavis

# %%
# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from gensim import corpora
from gensim.models import LdaModel, LdaMulticore,  CoherenceModel
from gensim import models
import gensim.downloader as api
from gensim.utils import simple_preprocess, lemmatize
from gensim.corpora.dictionary import Dictionary
import nltk
import spacy
from nltk.corpus import stopwords

# %%
files.upload()
# Out:
#      <input type="file" id="files-541a93ce-cb6e-4928-afd2-c435e9ef10af" name="files[]" multiple disabled />
#      <output id="result-541a93ce-cb6e-4928-afd2-c435e9ef10af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Rain_book.txt to Rain_book.txt
# ...

# %%
with open('Rain_book.txt', 'r',encoding='utf-8') as myfile:
    rain_data = myfile.read()

# %%
rain_data[0:100]
# Out:
# '\ufeffThursday, January 12, 2017\n\nONE DAY AT A TIME: \nA PERSONAL LIFELINE HISTORY\n\nRein Peterson\n\nBOOK ON'

# %%
rainbook = rain_data.split('APPENDIX')[0].strip()

# %%
rainbook_data = re.sub('(\t)', ' ', rainbook)# remove the tabs

# %%
para = [re.sub('(\n)',' ',t) for t in rainbook_data.split('.\n')] #split into paragraphs and then remove the \n

# %%
para = [re.sub(u"(\ufeff|\xa0)", " ", t) for t in para] # remove some of the unicode controls

# %%
sentences = [nltk.sent_tokenize(sent) for sent in para]

# %%
len(sentences)
# Out:
# 2602

# %%
stop_words = stopwords.words('english')

# %%
stop_words = stop_words + ['com', 'edu', 'subject', 'lines', 'organization', 'would', 'article', 'could','in','of']

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

# %%
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(para, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[para], threshold=100)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/models/phrases.py:598: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")

# %%
def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

# %%
def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# %%
texts = list(sent_to_words(para))

# %%
texts_nostops = remove_stopwords(texts)

# %%
print(texts[0:1])
print(texts_nostops[0:1])
# Out:
# [['thursday', 'january', 'one', 'day', 'at', 'time', 'personal', 'lifeline', 'history', 'rein', 'peterson', 'book', 'one', 'in', 'the', 'beginning', 'we', 'owe', 'it', 'all', 'to', 'yesteryears']]
# [['thursday', 'january', 'one', 'day', 'time', 'personal', 'lifeline', 'history', 'rein', 'peterson', 'book', 'one', 'beginning', 'owe', 'yesteryears']]

# %%
# Form Bigrams
texts_bigrams = make_bigrams(texts_nostops)

# %%
texts_bigrams[0:1]
# Out:
# [['thursday', 'january', 'one', 'day', 'time', 'personal', 'lifeline', 'history', 'rein', 'peterson', 'book', 'one', 'beginning', 'owe', 'yesteryears']]

# %%
texts_lemmatized = lemmatization(texts_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

# %%
# Create dictionary; expects array as input
dct = corpora.Dictionary(texts_lemmatized)

# %%
dct.filter_extremes(no_below=10, no_above=0.2)

# %%
# Get information about the dictionary
print(dct)
# Out:
# Dictionary(1695 unique tokens: ['book', 'day', 'history', 'january', 'personal']...)

# %%
# Show the word to id map
print(dct.token2id)
# Out:
# {'book': 0, 'day': 1, 'history': 2, 'january': 3, 'personal': 4, 'peterson': 5, 'time': 6, 'actually': 7, 'degree': 8, 'forever': 9, 'happen': 10, 'least': 11, 'lose': 12, 'make': 13, 'matter': 14, 'memory': 15, 'remember': 16, 'suppose': 17, 'tell': 18, 'think': 19, 'today': 20, 'alive': 21, 'allow': 22, 'also': 23, 'canadian': 24, 'collapse': 25, 'create': 26, 'event': 27, 'family': 28, 'first': 29, 'hero': 30, 'house': 31, 'keep': 32, 'let': 33, 'local': 34, 'monument': 35, 'nation': 36, 'old': 37, 'original': 38, 'people': 39, 'preserve': 40, 'settler': 41, 'child': 42, 'decision': 43, 'especially': 44, 'sort': 45, 'try': 46, 'use': 47, 'war': 48, 'write': 49, 'year': 50, 'action': 51, 'always': 52, 'appreciate': 53, 'approach': 54, 'dead': 55, 'die': 56, 'effort': 57, 'full': 58, 'great': 59, 'hang': 60, 'heart': 61, 'hope': 62, 'influence': 63, 'involve': 64, 'land': 65, 'lie': 66, 'little': 67, 'live': 68, 'may': 69, 'moment': 70, 'reach': 71, 'really': 72, 'respect': 73, 'tog
# ...

# %%
mycorpus = [dct.doc2bow(doc, allow_update=True) for doc in texts_lemmatized]

# %%
word_counts = [[(dct[id], count) for id, count in line] for line in mycorpus]

# %%
word_counts[0:10]
# Out:
# [[('book', 1), ('day', 1), ('history', 1), ('january', 1), ('personal', 1), ('peterson', 1), ('time', 1), ('beginning', 1), ('lifeline', 1), ('owe', 1), ('rein', 1), ('thursday', 1), ('yesteryear', 1)], [('personal', 1), ('actually', 1), ('degree', 1), ('forever', 1), ('happen', 1), ('least', 1), ('lose', 1), ('make', 1), ('matter', 1), ('memory', 1), ('remember', 2), ('suppose', 1), ('tell', 1), ('think', 1), ('today', 1), ('identity', 1), ('mixed', 1), ('myth', 1), ('poseur', 1), ('selective', 1)], [('history', 2), ('memory', 1), ('alive', 1), ('allow', 1), ('also', 1), ('canadian', 1), ('collapse', 1), ('create', 1), ('event', 1), ('family', 1), ('first', 1), ('hero', 1), ('house', 1), ('keep', 1), ('let', 1), ('local', 1), ('monument', 1), ('nation', 1), ('old', 1), ('original', 1), ('people', 1), ('preserve', 1), ('settler', 1), ('ancestor', 1), ('ancestry', 1), ('barn', 1), ('commemorate', 1), ('decay', 1), ('naturally', 1), ('northwest', 1), ('pacific', 1), ('pole', 2), ('prai
# ...

# %% [markdown]
# ###LDA

# %%
lda_model = LdaMulticore(corpus=mycorpus,
                         id2word=dct,
                         random_state=100,
                         num_topics=4,
                         passes=10,
                         chunksize=1000,
                         batch=False,
                         alpha='asymmetric',
                         decay=0.5,
                         offset=64,
                         eta=None,
                         eval_every=0,
                         iterations=100,
                         gamma_threshold=0.001,
                         per_word_topics=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
# ...

# %%
# save the model
lda_model.save('lda_model.model')

# See the topics
lda_model.print_topics(-1)
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# ...

# %%
for c in lda_model[mycorpus[5:9]]:
    print("Document Topics      : ", c[0])      # [(Topics, Perc Contrib)]
    print("Word id, Topics      : ", c[1][:3])  # [(Word id, [Topics])]
    print("Phi Values (word id) : ", c[2][:2])  # [(Word id, [(Topic, Phi Value)])]
    print("Word, Topics         : ", [(dct[wd], topic) for wd, topic in c[1][:2]])   # [(Word, [Topics])]
    print("Phi Values (word)    : ", [(dct[wd], topic) for wd, topic in c[2][:2]])  # [(Word, [(Topic, Phi Value)])]
    print("------------------------------------------------------\n")
# Out:
# Document Topics      :  [(0, 0.021226684), (1, 0.015545694), (2, 0.012465933), (3, 0.01044315), (5, 0.9069215)]
# Word id, Topics      :  [(4, [5]), (52, [5]), (79, [5])]
# Phi Values (word id) :  [(4, [(5, 0.99928313)]), (52, [(5, 0.9994428)])]
# Word, Topics         :  [('personal', [5]), ('always', [5])]
# Phi Values (word)    :  [('personal', [(5, 0.99928313)]), ('always', [(5, 0.9994428)])]
# ------------------------------------------------------
#
# Document Topics      :  [(0, 0.041061133), (1, 0.03132449), (2, 0.8241655), (3, 0.020886287), (4, 0.017969962), (5, 0.015768357), (6, 0.014047089), (7, 0.012664808), (8, 0.011530203), (9, 0.01058217)]
# Word id, Topics      :  [(82, [2]), (1746, [2]), (1747, [2])]
# Phi Values (word id) :  [(82, [(2, 0.9974419)]), (1746, [(2, 0.9995271)])]
# Word, Topics         :  [('man', [2]), ('hate', [2])]
# Phi Values (word)    :  [('man', [(2, 0.9974419)]), ('hate', [(2, 0.9995271)])]
# ------------------------------------------------------
# ...

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, mycorpus, dct)
vis
# Out:
# /usr/local/lib/python3.6/dist-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0     -0.180203 -0.004775       1        1  46.185062
# 1     -0.136396  0.009101       2        1  18.566973
# 4     -0.107038  0.064771       3        1   8.480282
# 5     -0.102395 -0.027162       4        1   7.546294
# 11    -0.029647 -0.150609       5        1   3.860436
# 10    -0.042363  0.086406       6        1   3.801899
# 8      0.000475  0.018191       7        1   3.108379
# 3      0.002684  0.031941       8        1   2.593550
# 6      0.021044 -0.053428       9        1   2.147830
# ...

# %% [markdown]
# ##Summary

# %%
import gensim
from gensim import corpora
from pprint import pprint
import numpy as np
from gensim import models
from gensim.utils import simple_preprocess
from gensim.summarization import summarize

# %%
documents = ["The Saudis are preparing a report that will acknowledge that Saudi journalist. Jamal Khashoggi's death was the result of aninterrogation that went wrong, one that was intended to lead to his abduction from Turkey, according to two sources."]

# %%
documents_2 = '''"The intersection graph of paths in trees",
               "Graph minors IV Widths of trees and well quasi ordering",
               "Graph minors A survey"'''

# %%
# !pip install spacy -qq

# %%
import spacy
nlp = spacy.load('en')
tkns = nlp(documents_2)

# %%
title = summarize(documents_2,word_count=5)

# %%
print(title)
# Out:
# "Graph minors IV Widths of trees and well quasi ordering",
